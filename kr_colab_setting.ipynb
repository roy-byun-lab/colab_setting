# %% [markdown]
# # 환경설정
# 참고:
# 1. https://theorydb.github.io/dev/2019/08/23/dev-ml-colab/
# 2. https://m.blog.naver.com/j7youngh/222817370952

# %%
#코랩 서버 스팩 확인
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 12327932440402348854
#  xla_global_id: -1]

# %%
#코랩 서버 스팩 확인(플랫폼 확인)
import platform
platform.platform()
# Out:
# 'Linux-6.1.85+-x86_64-with-glibc2.35'

# %%
#코랩 서버 스팩 확인(운영체계 확인)
# !cat /etc/issue.net
# Out:
# Ubuntu 22.04.3 LTS

# %%
#코랩 서버 스팩 확인(CPU사양 확인)
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0xffffffff
# cpu MHz		: 2199.998
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa mmio_stale_data retbleed bhi
# ...

# %%
#코랩 서버 스팩 확인(메모사양 확인)
# !cat /proc/meminfo

# %%
#코랩 서버 스팩 확인(디스크 사양 확인)
# !df -h

# %%
#코랩 서버 스팩 확인(파이썬 버전 확인)
# !python --version

# %% [markdown]
# # 기본

# %%
'''
매직 명령어는 %, %%를 이용하는데 %는 한 줄 안에서 명령어를 실행(line), %%는  여러 줄(cell)의 명령어를 수행하게 된다.
'''
#파일처리(만들기_쓰기)
# %%writefile  test.py
print('hello world!')
'''셀 명령문 실행(!), cat: 파일 내용 읽기'''
#파일내용확인
# !cat test.py

# test.py 실행시키기
# %run test.py

#파일 다운로드
from google.colab import files
# 브라우저에 다운로드 됨을 확인할 수 있다.
files.download('test.py')

#클라우드에 파일 업로드
myupload = files.upload()

#업로드 된 파일 확인
# !ls
# Out:
# Writing test.py

# %%
#구글드라이브 연동
import os
print(os.getcwd())
# !ls

# 실행시 등장하는 URL을 클릭하여 허용해주면 인증KEY가 나타난다. 복사하여 URL아래 빈칸에 붙여넣으면 마운트에 성공하게된다.
from google.colab import drive
drive.mount('./MyDrive')

# 마운트된 내 드라이브를 확인해보자
# !ls

# 해당 드라이브로 이동
# 내 드라이브는 원격서버가 아니라 로컬서버로 간주하므로 명령어 실행시 앞단에 !를 붙이지 않는다.
cd MyDrive/My Drive

# 내드라이브의 전체 목록이 나타난다.
ls

# 특정파일을 가져오고 싶은 경우 다음과 같이 접근한다.
import pandas as pd
df = pd.read_csv("./MyDrive/test/test.csv")

# %% [markdown]
# # 마크다운

# %%
#마크다운 사용 예
참고: https://theorydb.github.io/envops/2019/05/22/envops-blog-how-to-use-md/

# %% [markdown]
# # 그외

# %% [markdown]
# 1.별도로 파이썬 설치가 필요없다
#
# 2.데이터 분석에 사용되는 라이브러리가 설치되어있다.
#
# 3.GPU를 무료로 사용할 수 있다.
#
# 4.github과 연동이 가능하다.

# %%
#코랩(Colab)의 주피터 노트북(Jupyter notebook) 사용 팁
help(max)

# %%
'''
코랩은 Jupyter Notebook 환경이기 때문에 파이썬 파일(확장자 .py)을 바로 실행시키지 못한다.
또한  파이썬 명령문을 쓰지만 파이썬 파일(.py)로 저장되지 않고 .ipynb 파일로 저장된다.
따라서 파이썬 파일로 저장하거나 실행시키기 위해서는 매직 명령어(magic commands)인 "%"(line 명령어)나 "%%"(cell 명령어) 써서 작성한다. .
'''
